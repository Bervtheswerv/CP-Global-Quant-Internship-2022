# %% [markdown]
# ### Client Sub and Port Dec 2021

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import warnings
warnings.filterwarnings('ignore')
import os

# %matplotlib inline

# %%
data = pd.read_excel('/Users/bervynwong/Desktop/Educational Documents/Trading & Financial Markets/Client Sub & Port Dec 2021.xlsx', sheet_name='BAK Jun 15 test')
data.columns = ['Date', 'NAV', 'Date of (re-)investment', 'ROI', 'CAGR' ]
data.tail()
# Out:
#          Date     NAV Date of (re-)investment  ROI  CAGR
# 74 2021-08-01  264.58                     NaN  NaN   NaN
# 75 2021-09-01  272.14                     NaN  NaN   NaN
# 76 2021-10-01  273.14                     NaN  NaN   NaN
# 77 2021-11-01  273.89                     NaN  NaN   NaN
# 78 2021-12-01  273.83                     NaN  NaN   NaN

# %%
data.plot(x='Date', y='NAV', figsize=(20,12))
plt.title('CP Multi-Strategy Fund NAV (as of Dec 2021) - BAK Jun 15 ')
plt.ylabel('Net Asset Value (NAV)')
plt.xlabel('Year')
plt.grid()
plt.show();

# %%
HVM_data = yf.download(tickers='^VIX', interval='1mo')
HVM_data = HVM_data.drop(columns = ['Open', 'High', 'Low', 'Close','Volume'])
display(HVM_data)

HVM_data.rolling(window = 30, min_periods=1).median().round(1)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Adj Close
# Date
# 1990-02-01  21.990000
# 1990-03-01  19.730000
# 1990-04-01  19.520000
# 1990-05-01  17.370001
# 1990-06-01  15.500000
# ...               ...
# 2021-11-01  27.190001
# 2021-12-01  17.219999
# 2022-01-01  24.830000
# 2022-02-01  28.330000
# 2022-02-15  25.700001
#
# [386 rows x 1 columns]
#             Adj Close
# Date
# 1990-02-01       22.0
# 1990-03-01       20.9
# 1990-04-01       19.7
# 1990-05-01       19.6
# 1990-06-01       19.5
# ...               ...
# 2021-11-01       20.0
# 2021-12-01       20.0
# 2022-01-01       21.7
# 2022-02-01       22.9
# 2022-02-15       23.8
#
# [386 rows x 1 columns]

# %%
# Take all the months with 31 days
if month[month[no. of days] == 31]:
    execute code

# Feb is the exception that has 2 possibilities
elif month == Feb:

    if feb[days] == 28:
        execute code

    elif feb[days] == 29:
        execute code # leap year

# Lastly, months with only 30 days
elif month[month[no. of days] == 30]:
    execute code
